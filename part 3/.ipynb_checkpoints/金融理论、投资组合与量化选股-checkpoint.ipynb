# %% [markdown]
# # 18 资产收益率和风险
# ## 18.1 单期和多期简单收益率
# ### 18.1.1 单期简单收益率
# - 单期简单收益率
# ![image.png](attachment:image.png)
# - 简单毛收益率
# ![image-2.png](attachment:image-2.png)
# ### 18.1.2 多期简单收益率
# - 2期简单收益率
# ![image-3.png](attachment:image-3.png)
# - k期简单收益率
# ![image-4.png](attachment:image-4.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
stock = pd.read_csv('./018/stockszA.csv', index_col='Trddt')
stock.head()
# Out:
#           Stkcd  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd     Dnvaltrd  \
# Trddt
# 2014/1/2      1   12.12  12.30  12.05   12.23  48991089  596223744.4
# 2014/1/3      1   12.15  12.16  11.78   11.93  55111484  656631302.4
# 2014/1/6      1   11.89  12.00  11.50   11.67  58211823  679280389.7
# 2014/1/7      1   11.53  11.76  11.51   11.63  33840749  393977581.0
# 2014/1/8      1   11.64  11.95  11.53   11.76  45776816  538436179.5
#
#               Dsmvosd       Dsmvtll    Dretwd    Dretnd    Adjprcwd  \
# Trddt
# 2014/1/2  68193279.93  1.002537e+08 -0.001633 -0.001633  686.893127
# 2014/1/3  66520509.37  9.779451e+07 -0.024530 -0.024530  670.043745
# 2014/1/6  65070774.88  9.566320e+07 -0.021794 -0.021794  655.440948
# 2014/1/7  64847738.81  9.533530e+07 -0.003428 -0.003428  653.194364
# 2014/1/8  65572606.05  1.119640e+08  0.011178  0.011178  660.495763
#
#             Adjprcnd  Markettype    Capchgdt  Trdsta
# Trddt
# 2014/1/2  586.277691           4  2013/11/12       1
# 2014/1/3  571.896390           4  2013/11/12       1
# 2014/1/6  559.432596           4  2013/11/12       1
# 2014/1/7  557.515089           4  2013/11/12       1
# 2014/1/8  563.746986           4    2014/1/8       1

# %%
# 万科股票数据
vanke = stock[stock.Stkcd == 2]

# 收盘价
close = vanke.Clsprc
close.index = pd.to_datetime(close.index)
close.head()
# Out:
# Trddt
# 2014-01-02    7.99
# 2014-01-03    7.84
# 2014-01-06    7.48
# 2014-01-07    7.43
# 2014-01-08    7.42
# Name: Clsprc, dtype: float64

# %%
# 收盘及滞后一天
lagclose = close.shift(1)
lagclose.head()
# Out:
# Trddt
# 2014-01-02     NaN
# 2014-01-03    7.99
# 2014-01-06    7.84
# 2014-01-07    7.48
# 2014-01-08    7.43
# Name: Clsprc, dtype: float64

# %%
# 单期简单收益率
simpleret = (close - lagclose) / lagclose
simpleret.head()
# Out:
# Trddt
# 2014-01-02         NaN
# 2014-01-03   -0.018773
# 2014-01-06   -0.045918
# 2014-01-07   -0.006684
# 2014-01-08   -0.001346
# Name: Clsprc, dtype: float64

# %%
# 合并数据
calret = pd.DataFrame({'close': close, 'lagclose': lagclose, 'simpleret': simpleret})
calret.head()
# Out:
#             close  lagclose  simpleret
# Trddt
# 2014-01-02   7.99       NaN        NaN
# 2014-01-03   7.84      7.99  -0.018773
# 2014-01-06   7.48      7.84  -0.045918
# 2014-01-07   7.43      7.48  -0.006684
# 2014-01-08   7.42      7.43  -0.001346

# %%
# 2期简单收益率
simpleret2 = (close - close.shift(2)) /  close.shift(2)
simpleret2.head()
# Out:
# Trddt
# 2014-01-02         NaN
# 2014-01-03         NaN
# 2014-01-06   -0.063830
# 2014-01-07   -0.052296
# 2014-01-08   -0.008021
# Name: Clsprc, dtype: float64

# %%
calret['simpleret2'] = simpleret2
calret.head()
# Out:
#             close  lagclose  simpleret  simpleret2
# Trddt
# 2014-01-02   7.99       NaN        NaN         NaN
# 2014-01-03   7.84      7.99  -0.018773         NaN
# 2014-01-06   7.48      7.84  -0.045918   -0.063830
# 2014-01-07   7.43      7.48  -0.006684   -0.052296
# 2014-01-08   7.42      7.43  -0.001346   -0.008021

# %% [markdown]
# ### 18.1.3 Python 函数计算简单收益率

# %%
import ffn
ffnSimpleret = ffn.to_returns(close)
ffnSimpleret.head()
# Out:
# Trddt
# 2014-01-02         NaN
# 2014-01-03   -0.018773
# 2014-01-06   -0.045918
# 2014-01-07   -0.006684
# 2014-01-08   -0.001346
# Name: Clsprc, dtype: float64

# %% [markdown]
# ### 18.1.4 单期与多期简单收益率的关系
# - 两期收益率
# ![image.png](attachment:image.png)
# - 复利
# ![image-2.png](attachment:image-2.png)
# - k期收益率
# ![image-3.png](attachment:image-3.png)
# - 算术平均收益率
# ![image-4.png](attachment:image-4.png)
# - 几何平均收益率
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### 18.1.5 年华收益率
# - 年化收益率的计算与复利相关，假设持有资产时间为 T 期，获取到收益率为 RT，一年共 m 个单期，则年华收益率为：
# ![image.png](attachment:image.png)
# - 也可以用下面公式计算，将 T 时段获取的收益复利 m/T次
# ![image-2.png](attachment:image-2.png)
# - RT 不是直接给出，由 T 期的单期收益率计算
# ![image-3.png](attachment:image-3.png)
# - RT 用复利的计算方式
# ![image-4.png](attachment:image-4.png)

# %%
# python 计算年华简单收益率
# 假设一年 245个交易日
annualize = (1 + simpleret).cumprod()[-1] ** (245/len(simpleret)) - 1
annualize
# Out:
# 0.5660614874349641

# %%
def fun_annualize(returns, period):
    if period == 'day':
        return (1 + returns).cumprod()[-1] ** (245/len(returns)) - 1
    elif period == 'month':
        return (1+returns).cumprod()[-1]**(12/len(returns)) - 1
    elif period == 'quarter':
        return (1+returns).cumprod()[-1] ** (4/len(returns)) - 1
    elif period == 'year':
        return (1+returns).cumprod()[-1] ** (1/len(returns)) - 1
    else:
        raise Exception('Wrong period')

# %%
fun_annualize(simpleret, 'day')
# Out:
# 0.5660614874349641

# %% [markdown]
# ### 18.1.6 考虑股利分红的简单收益率
# - 除息价
# ![image.png](attachment:image.png)
# - 除权价
# ![image-2.png](attachment:image-2.png)
# - 除权除息价
# ![image-3.png](attachment:image-3.png)
# - t 期单期收益率
# ![image-4.png](attachment:image-4.png)
# - 股息率 股息和股价的比率
# ![image-5.png](attachment:image-5.png)
# - 市盈率/本益比
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## 18.2 连续复利收益率
# - 连续复利： 投资期数趋于无穷大，不同期之间的时间间隔无穷小，分分秒秒都在复利。单期简单收益率为 R，有 n 个复利结算周期，T 期收益率：
# ![image.png](attachment:image.png)
# - T 期连续复利的收益率：
# ![image-2.png](attachment:image-2.png)
# - 收益率
# ![image-3.png](attachment:image-3.png)

# %%
import numpy as np
comporet = np.log(close / lagclose)
comporet.head()
# Out:
# Trddt
# 2014-01-02         NaN
# 2014-01-03   -0.018952
# 2014-01-06   -0.047006
# 2014-01-07   -0.006707
# 2014-01-08   -0.001347
# Name: Clsprc, dtype: float64

# %%
# 使用 ffn 包中的函数
ffnComporet = ffn.to_log_returns(close)
ffnComporet.head()
# Out:
# Trddt
# 2014-01-02         NaN
# 2014-01-03   -0.018952
# 2014-01-06   -0.047006
# 2014-01-07   -0.006707
# 2014-01-08   -0.001347
# Name: Clsprc, dtype: float64

# %% [markdown]
# ### 18.2.1 多期连续复利收益率
# - k 期连续复利收益率：
# ![image-2.png](attachment:image-2.png)

# %%
comporet2 = np.log(close / close.shift(2))
comporet2.head()
# Out:
# Trddt
# 2014-01-02         NaN
# 2014-01-03         NaN
# 2014-01-06   -0.065958
# 2014-01-07   -0.053713
# 2014-01-08   -0.008054
# Name: Clsprc, dtype: float64

# %% [markdown]
# ### 18.2.3 单期与多期连续复利收益率的关系
# - 2 期连续复利收益率
# ![image.png](attachment:image.png)
# - k 期连续复利收益率 : 单期加总即为多期
# ![image-2.png](attachment:image-2.png)

# %%
comporet = comporet.dropna()
comporet + comporet.shift(1)
# Out:
# Trddt
# 2014-01-03         NaN
# 2014-01-06   -0.065958
# 2014-01-07   -0.053713
# 2014-01-08   -0.008054
# 2014-01-09    0.004030
#                 ...
# 2015-04-08    0.027138
# 2015-04-09    0.064903
# 2015-04-10    0.035540
# 2015-04-13   -0.018615
# 2015-04-14   -0.014065
# Name: Clsprc, Length: 310, dtype: float64

# %% [markdown]
# ## 18.3 绘制收益图

# %%
import matplotlib.pyplot as plt
simpleret.plot()
# Out:
# <AxesSubplot:xlabel='Trddt'>

# %%
((1+simpleret).cumprod() - 1).plot()
# Out:
# <AxesSubplot:xlabel='Trddt'>

# %% [markdown]
# ## 18.4 资产风险的来源
# ### 18.4.1 市场风险
# ### 18.4.2 利率风险
# ### 18.4.3 汇率风险
# ### 18.4.4 流动性风险
# ### 18.4.5 信用风险
# ### 18.4.6 通货膨胀风险
# ### 18.4.7 营运风险

# %% [markdown]
# ## 18.5 资产风险的测度
# - 单个资产的风险：
# ![image.png](attachment:image.png)
# - 收益率 R 是离散分布
# ![image-2.png](attachment:image-2.png)
# - R 服从连续分布
# ![image-3.png](attachment:image-3.png)

# %%
SAPower = pd.read_csv('./018/SAPower.csv', index_col='Date')
SAPower.index = pd.to_datetime(SAPower.index)
SAPower.head()
# Out:
#             Unnamed: 0   Open   High    Low  Close   Volume
# Date
# 2014-01-01           1  14.24  14.24  14.24  14.24        0
# 2014-01-02           2  14.23  14.57  14.15  14.55  7093500
# 2014-01-03           3  14.43  14.50  14.09  14.24  6885700
# 2014-01-06           4  14.14  14.14  13.50  13.68  5462500
# 2014-01-07           5  13.68  14.14  13.39  13.91  4491900

# %%
DalianRP = pd.read_csv('./018/DalianRP.csv', index_col='Date', parse_dates=['Date'])
DalianRP.head()
# Out:
#             Unnamed: 0    Open    High     Low   Close   Volume
# Date
# 2014-01-01           1  15.502  15.502  15.502  15.502        0
# 2014-01-02           2  15.732  15.870  15.203  15.640  2946700
# 2014-01-03           3  15.548  16.399  15.410  16.169  6475400
# 2014-01-06           4  16.192  16.261  15.111  15.180  4401100
# 2014-01-07           5  14.973  15.387  14.674  14.927  2718000

# %%
returnS = ffn.to_returns(SAPower.Close)
returnD = ffn.to_returns(DalianRP.Close)

# %%
returnS.std()
# Out:
# 0.041511404614033375

# %%
returnD.std()
# Out:
# 0.020319411733180383

# %% [markdown]
# ### 18.5.2 下行风险
# - 目标收益率：可接受的最低收益率 (MARR)代表
# - 下行偏差描述的是低于 MARR 的收益率的发散程度
# ![image.png](attachment:image.png)
# - R1，R2，... RT 为R的随机样本，样本的下行偏差：
# ![image-2.png](attachment:image-2.png)

# %%
def cal_half_risk(returns):
    mu = returns.mean()
    temp = returns[returns < mu]
    return (sum((mu - temp) ** 2) / len(returns)) ** 0.5

cal_half_risk(returnS)
# Out:
# 0.03552493855977126

# %%
cal_half_risk(returnD)
# Out:
# 0.013673338707193382

# %% [markdown]
# ### 18.5.3 风险价值
# - 风险价值 VaR 是给定的置信水平的目标时段下预期的最大损失，或最坏情况下的损失。换句话说，在市场正常波动的条件下，在一定概率水平α%下，某一金融资产或金融资产组合的VaR(α, Δt) 是在未来一段时间 Δt 内的最大可能损失：
# ![image.png](attachment:image.png)
# - 估算方法
#     - 历史模拟法
#     - 协方差矩阵法
#     - 蒙特卡罗模拟法

# %%
# 历史模拟法
returnS.quantile(0.05)
# Out:
# -0.043192456894806296

# %%
returnD.quantile(0.05)
# Out:
# -0.03408596308105866

# %%
# 协方差矩阵法
from scipy.stats import norm
norm.ppf(0.05, returnS.mean(), returnS.std())
# Out:
# -0.06621086216022148

# %%
norm.ppf(0.05, returnD.mean(), returnD.std())
# Out:
# -0.03274944602236822

# %% [markdown]
# ### 18.5.4 期望亏空
# - 期望亏空是为了弥补 VaR 理论上的缺点。
# - 期望亏空考虑的是超越 VaR 水平的损失的期望值，也就是最坏的α% 损失的平均值
# ![image.png](attachment:image.png)

# %%
returnS[returnS <= returnS.quantile(0.05)].mean()
# Out:
# -0.09673316088802106

# %%
returnD[returnD <= returnD.quantile(0.05)].mean()
# Out:
# -0.04536728238570146

# %% [markdown]
# ### 18.5.5 最大回撤
# - 回撤：某资产在时刻 T 的回撤指资产在(0,T)的最高峰与现价值 PT 之间的回落值
# ![image.png](attachment:image.png)
# - 回撤率
# ![image-2.png](attachment:image-2.png)
# - 最大回撤：资产在 T 时刻的最大回撤 MDD(T) ，资产在时段(0,T)内回撤的最大值
# ![image-3.png](attachment:image-3.png)
# - 最大回撤率
# ![image-4.png](attachment:image-4.png)
#
# - 以收益率计算回撤L
#     - 资产收益率序列为 R1,R2,...,RT，T时点的回撤值：
#     ![image-8.png](attachment:image-8.png)
#     - 回撤率：
#     ![image-7.png](attachment:image-7.png)
#     - 最大回撤
#     ![image-6.png](attachment:image-6.png)
#     - 最大回撤率
#     ![image-5.png](attachment:image-5.png)

# %%
 import datetime

# %%
r = pd.Series([0, 0.1, -0.1, -0.01, 0.01, 0.02],
              index=[datetime.date(2015, 7, x) for x in range(3, 9)])
r
# Out:
# 2015-07-03    0.00
# 2015-07-04    0.10
# 2015-07-05   -0.10
# 2015-07-06   -0.01
# 2015-07-07    0.01
# 2015-07-08    0.02
# dtype: float64

# %%
value = (1 + r).cumprod()
value
# Out:
# 2015-07-03    1.000000
# 2015-07-04    1.100000
# 2015-07-05    0.990000
# 2015-07-06    0.980100
# 2015-07-07    0.989901
# 2015-07-08    1.009699
# dtype: float64

# %%
D = value.cummax() - value
D
# Out:
# 2015-07-03    0.000000
# 2015-07-04    0.000000
# 2015-07-05    0.110000
# 2015-07-06    0.119900
# 2015-07-07    0.110099
# 2015-07-08    0.090301
# dtype: float64

# %%
d = D / (D + value)
d
# Out:
# 2015-07-03    0.000000
# 2015-07-04    0.000000
# 2015-07-05    0.100000
# 2015-07-06    0.109000
# 2015-07-07    0.100090
# 2015-07-08    0.082092
# dtype: float64

# %%
MDD = D.max()
MDD
# Out:
# 0.1199

# %%
mdd = d.max()
mdd
# Out:
# 0.109

# %%
# ffn 中的 calc_max_drawdown()
ffn.calc_max_drawdown((1+returnS).cumprod())
# Out:
# -0.5676392572944298

# %%
ffn.calc_max_drawdown((1 + returnD).cumprod())
# Out:
# -0.24797570850202444

# %% [markdown]
# # 19 投资组合理论及其拓展
# ## 19.1 投资组合的收益率与风险
# - 两种风险资产，资产 A 和资产 B 的随机收益率为 RA 和 RB，投资比例为 wA 和 wB，且 wA+wB=1。初期资本为 W0。
#     - 投资组合收益率
#     ![image.png](attachment:image.png)
#     - 投资组合方差（收益率的方差指代风险）
#     ![image-2.png](attachment:image-2.png)
#     - 标准差
#     ![image-3.png](attachment:image-3.png)
# - N 中风险资产，资产收益率为 RA, RB, ..., RN，投资比重为 w1, w2,..., wN。初期资本为 W0
#     - 投资组成收益率
#     ![image-4.png](attachment:image-4.png)
#     - 投资组成期望收益率
#     ![image-5.png](attachment:image-5.png)
#     - 方差
#     ![image-6.png](attachment:image-6.png)

# %%
# python 绘制出不通相关系数下，投资组合标准差随投资比例遍地的情况
import numpy as np
import math

# 组合收益率


def cal_mean(frac):
    return (0.08 * frac + 0.15 * (1 - frac))


# 不同投资比重下的组合收益率
mean = list(map(cal_mean, [x/50 for x in range(51)]))

# 标准差
sd_mat=np.array([list(map(lambda x: math.sqrt((x**2)*0.12**2+((1-x)**2)*0.25**2+2*x*(1-x)*(-1.5+i*0.5)*0.12*0.25),[x/50 for x in range(51)])) for i in range(1,6)])

plt.plot(sd_mat[0, :], mean, label = '-1')
plt.plot(sd_mat[1, :], mean, label = '-0.5')
plt.plot(sd_mat[2, :], mean, label = '0')
plt.plot(sd_mat[3, :], mean, label = '0.5')
plt.plot(sd_mat[4, :], mean, label = '1')
plt.legend(loc='upper left')
plt.show()
# Out:
# <ipython-input-40-8cc0d368c2b4>:25: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
